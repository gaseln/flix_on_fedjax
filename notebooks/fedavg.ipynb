# %%
from absl import app

import fedjax

import jax
import jax.numpy as jnp

# %%
train_fd, test_fd = fedjax.datasets.emnist.load_data(only_digits=False)
# Out:
# Reusing cached file '/home/gasanoe/.cache/fedjax/federated_emnist_train.sqlite'
# Reusing cached file '/home/gasanoe/.cache/fedjax/federated_emnist_test.sqlite'

# %%
model = fedjax.models.emnist.create_conv_model(only_digits=False)

# %%
def loss(params, batch, rng):
    # `rng` used with `apply_for_train` to apply dropout during training.
    preds = model.apply_for_train(params, batch, rng)
    # Per example loss of shape [batch_size].
    example_loss = model.train_loss(batch, preds)
    return jnp.mean(example_loss)

# %%
grad_fn = jax.jit(jax.grad(loss))

# %%
client_optimizer = fedjax.optimizers.sgd(learning_rate=10**(-1.5))
server_optimizer = fedjax.optimizers.adam(learning_rate=10**(-2.5), b1=0.9, b2=0.999, eps=10**(-4))
# Hyperparameters for client local traing dataset preparation.
client_batch_hparams = fedjax.ShuffleRepeatBatchHParams(batch_size=20)
algorithm = fedjax.algorithms.fed_avg.federated_averaging(grad_fn, client_optimizer,
                                          server_optimizer,
                                          client_batch_hparams)

# %%
# Initialize model parameters and algorithm server state.
init_params = model.init(jax.random.PRNGKey(17))

# %%
server_state = algorithm.init(init_params)

# Train and eval loop.
train_client_sampler = fedjax.client_samplers.UniformGetClientSampler(fd=train_fd, num_clients=10, seed=0)

# %%
for round_num in range(1, 1501):
    # Sample 10 clients per round without replacement for training.
    clients = train_client_sampler.sample()
    # Run one round of training on sampled clients.
    server_state, client_diagnostics = algorithm.apply(server_state, clients)
    print(f'[round {round_num}]', end='\r')
    # Optionally print client diagnostics if curious about each client's model
    # update's l2 norm.
    # print(f'[round {round_num}] client_diagnostics={client_diagnostics}')

    if round_num % 10 == 0:
      # Periodically evaluate the trained server model parameters.
      # Read and combine clients' train and test datasets for evaluation.
        client_ids = [cid for cid, _, _ in clients]
        train_eval_datasets = [cds for _, cds in train_fd.get_clients(client_ids)]
        test_eval_datasets = [cds for _, cds in test_fd.get_clients(client_ids)]
        train_eval_batches = fedjax.padded_batch_client_datasets(
          train_eval_datasets, batch_size=256)
        test_eval_batches = fedjax.padded_batch_client_datasets(
          test_eval_datasets, batch_size=256)

      # Run evaluation metrics defined in `model.eval_metrics`.
        train_metrics = fedjax.evaluate_model(model, server_state.params,
                                            train_eval_batches)
        test_metrics = fedjax.evaluate_model(model, server_state.params, test_eval_batches)
        print('')
        print(f'[round {round_num}] train_metrics={train_metrics}')
        print(f'[round {round_num}] test_metrics={test_metrics}')

# Save final trained model parameters to file.
fedjax.serialization.save_state(server_state.params, '/tmp/params')
# Out:
# [round 10]
# [round 10] train_metrics={'accuracy': DeviceArray(0.8026859, dtype=float32), 'loss': DeviceArray(0.6623511, dtype=float32)}
# [round 10] test_metrics={'accuracy': DeviceArray(0.7955556, dtype=float32), 'loss': DeviceArray(0.6655238, dtype=float32)}
# [round 20]
# [round 20] train_metrics={'accuracy': DeviceArray(0.8492724, dtype=float32), 'loss': DeviceArray(0.52056676, dtype=float32)}
# [round 20] test_metrics={'accuracy': DeviceArray(0.8475337, dtype=float32), 'loss': DeviceArray(0.46154043, dtype=float32)}
# [round 30]
# [round 30] train_metrics={'accuracy': DeviceArray(0.78894204, dtype=float32), 'loss': DeviceArray(0.6405203, dtype=float32)}
# [round 30] test_metrics={'accuracy': DeviceArray(0.7579909, dtype=float32), 'loss': DeviceArray(0.61889136, dtype=float32)}
# [round 40]
# [round 40] train_metrics={'accuracy': DeviceArray(0.8332388, dtype=float32), 'loss': DeviceArray(0.5279828, dtype=float32)}
# [round 40] test_metrics={'accuracy': DeviceArray(0.8, dtype=float32), 'loss': DeviceArray(0.5718099, dtype=float32)}
# [round 50]
# [round 50] train_metrics={'accuracy': DeviceArray(0.78327835, dtype=float32), 'loss': DeviceArray(0.625017, dtype=float32)}
# [round 50] test_metrics={'accuracy': DeviceArray(0.77033496, dtype=float32), 'loss': DeviceArray(0.66159075, dtype=float32)}
# [round 60]
# [round 60] train_metrics={'accuracy': DeviceArray(0.77711177, dtype=float32), 'loss': DeviceArray(0.70048463, dtype=float32)}
# [round 60] test_metrics={'accuracy': DeviceArray(0.8084112, dtype=float32), 'loss': DeviceArray(0.6485238, dtype=float32)}
# [round 70]
# [round 70] train_metrics={'accuracy': DeviceArray(0.83019656, dtype=float32), 'loss': DeviceArray(0.52090615, dtype=float32)}
# [round 70] test_metrics={'accuracy': DeviceArray(0.83455884, dtype=float32), 'loss': DeviceArray(0.48517832, dtype=float32)}
# [round 80]
# [round 80] train_metrics={'accuracy': DeviceArray(0.80386585, dtype=float32), 'loss': DeviceArray(0.5961507, dtype=float32)}
# [round 80] test_metrics={'accuracy': DeviceArray(0.7794118, dtype=float32), 'loss': DeviceArray(0.5745921, dtype=float32)}
# [round 90]
# [round 90] train_metrics={'accuracy': DeviceArray(0.8409302, dtype=float32), 'loss': DeviceArray(0.5317919, dtype=float32)}
# [round 90] test_metrics={'accuracy': DeviceArray(0.8266129, dtype=float32), 'loss': DeviceArray(0.5642777, dtype=float32)}
# [round 100]
# [round 100] train_metrics={'accuracy': DeviceArray(0.8248561, dtype=float32), 'loss': DeviceArray(0.5789075, dtype=float32)}
# [round 100] test_metrics={'accuracy': DeviceArray(0.81250006, dtype=float32), 'loss': DeviceArray(0.6617945, dtype=float32)}
# [round 110]
# [round 110] train_metrics={'accuracy': DeviceArray(0.84025556, dtype=float32), 'loss': DeviceArray(0.48563382, dtype=float32)}
# [round 110] test_metrics={'accuracy': DeviceArray(0.8472222, dtype=float32), 'loss': DeviceArray(0.52369875, dtype=float32)}
# [round 120]
# [round 120] train_metrics={'accuracy': DeviceArray(0.83113337, dtype=float32), 'loss': DeviceArray(0.49318817, dtype=float32)}
# [round 120] test_metrics={'accuracy': DeviceArray(0.8149606, dtype=float32), 'loss': DeviceArray(0.5955892, dtype=float32)}
# [round 130]
# [round 130] train_metrics={'accuracy': DeviceArray(0.8410973, dtype=float32), 'loss': DeviceArray(0.48130444, dtype=float32)}
# [round 130] test_metrics={'accuracy': DeviceArray(0.83856505, dtype=float32), 'loss': DeviceArray(0.47148025, dtype=float32)}
# [round 140]
# [round 140] train_metrics={'accuracy': DeviceArray(0.8709046, dtype=float32), 'loss': DeviceArray(0.4101171, dtype=float32)}
# [round 140] test_metrics={'accuracy': DeviceArray(0.8468085, dtype=float32), 'loss': DeviceArray(0.4473645, dtype=float32)}
# [round 150]
# [round 150] train_metrics={'accuracy': DeviceArray(0.83342874, dtype=float32), 'loss': DeviceArray(0.47656858, dtype=float32)}
# [round 150] test_metrics={'accuracy': DeviceArray(0.8627451, dtype=float32), 'loss': DeviceArray(0.45680732, dtype=float32)}
# [round 160]
# [round 160] train_metrics={'accuracy': DeviceArray(0.8430401, dtype=float32), 'loss': DeviceArray(0.45157185, dtype=float32)}
# [round 160] test_metrics={'accuracy': DeviceArray(0.8768116, dtype=float32), 'loss': DeviceArray(0.37021104, dtype=float32)}
# [round 170]
# [round 170] train_metrics={'accuracy': DeviceArray(0.8443507, dtype=float32), 'loss': DeviceArray(0.48938334, dtype=float32)}
# [round 170] test_metrics={'accuracy': DeviceArray(0.83265305, dtype=float32), 'loss': DeviceArray(0.57553303, dtype=float32)}
# [round 180]
# [round 180] train_metrics={'accuracy': DeviceArray(0.8119971, dtype=float32), 'loss': DeviceArray(0.5219904, dtype=float32)}
# [round 180] test_metrics={'accuracy': DeviceArray(0.826087, dtype=float32), 'loss': DeviceArray(0.5519885, dtype=float32)}
# [round 190]
# [round 190] train_metrics={'accuracy': DeviceArray(0.83521956, dtype=float32), 'loss': DeviceArray(0.45964006, dtype=float32)}
# [round 190] test_metrics={'accuracy': DeviceArray(0.8385827, dtype=float32), 'loss': DeviceArray(0.49034005, dtype=float32)}
# [round 200]
# [round 200] train_metrics={'accuracy': DeviceArray(0.83692527, dtype=float32), 'loss': DeviceArray(0.47635728, dtype=float32)}
# [round 200] test_metrics={'accuracy': DeviceArray(0.81097555, dtype=float32), 'loss': DeviceArray(0.48733276, dtype=float32)}
# [round 210]
# [round 210] train_metrics={'accuracy': DeviceArray(0.8478161, dtype=float32), 'loss': DeviceArray(0.46484467, dtype=float32)}
# [round 210] test_metrics={'accuracy': DeviceArray(0.84337354, dtype=float32), 'loss': DeviceArray(0.5331888, dtype=float32)}
# [round 220]
# [round 220] train_metrics={'accuracy': DeviceArray(0.8478039, dtype=float32), 'loss': DeviceArray(0.45093912, dtype=float32)}
# [round 220] test_metrics={'accuracy': DeviceArray(0.8761062, dtype=float32), 'loss': DeviceArray(0.36129105, dtype=float32)}
# [round 230]
# [round 230] train_metrics={'accuracy': DeviceArray(0.8273635, dtype=float32), 'loss': DeviceArray(0.49712786, dtype=float32)}
# [round 230] test_metrics={'accuracy': DeviceArray(0.7839196, dtype=float32), 'loss': DeviceArray(0.5522102, dtype=float32)}
# [round 240]
# [round 240] train_metrics={'accuracy': DeviceArray(0.8312217, dtype=float32), 'loss': DeviceArray(0.50347626, dtype=float32)}
# [round 240] test_metrics={'accuracy': DeviceArray(0.826087, dtype=float32), 'loss': DeviceArray(0.4809594, dtype=float32)}
# [round 250]
# [round 250] train_metrics={'accuracy': DeviceArray(0.88771933, dtype=float32), 'loss': DeviceArray(0.3113058, dtype=float32)}
# [round 250] test_metrics={'accuracy': DeviceArray(0.8850575, dtype=float32), 'loss': DeviceArray(0.41128364, dtype=float32)}
# [round 260]
# [round 260] train_metrics={'accuracy': DeviceArray(0.8019548, dtype=float32), 'loss': DeviceArray(0.6147744, dtype=float32)}
# [round 260] test_metrics={'accuracy': DeviceArray(0.8169643, dtype=float32), 'loss': DeviceArray(0.48547557, dtype=float32)}
# [round 270]
# [round 270] train_metrics={'accuracy': DeviceArray(0.8558188, dtype=float32), 'loss': DeviceArray(0.48855942, dtype=float32)}
# [round 270] test_metrics={'accuracy': DeviceArray(0.8928572, dtype=float32), 'loss': DeviceArray(0.4485507, dtype=float32)}
# [round 280]
# [round 280] train_metrics={'accuracy': DeviceArray(0.8018648, dtype=float32), 'loss': DeviceArray(0.5973231, dtype=float32)}
# [round 280] test_metrics={'accuracy': DeviceArray(0.7828283, dtype=float32), 'loss': DeviceArray(0.58586586, dtype=float32)}
# [round 290]
# [round 290] train_metrics={'accuracy': DeviceArray(0.82627124, dtype=float32), 'loss': DeviceArray(0.57697487, dtype=float32)}
# [round 290] test_metrics={'accuracy': DeviceArray(0.86010367, dtype=float32), 'loss': DeviceArray(0.42770302, dtype=float32)}
# [round 300]
# [round 300] train_metrics={'accuracy': DeviceArray(0.8495822, dtype=float32), 'loss': DeviceArray(0.42686298, dtype=float32)}
# [round 300] test_metrics={'accuracy': DeviceArray(0.85096157, dtype=float32), 'loss': DeviceArray(0.39572358, dtype=float32)}
# [round 310]
# [round 310] train_metrics={'accuracy': DeviceArray(0.829955, dtype=float32), 'loss': DeviceArray(0.5446852, dtype=float32)}
# [round 310] test_metrics={'accuracy': DeviceArray(0.8067633, dtype=float32), 'loss': DeviceArray(0.56389755, dtype=float32)}
# [round 320]
# [round 320] train_metrics={'accuracy': DeviceArray(0.88970953, dtype=float32), 'loss': DeviceArray(0.35822946, dtype=float32)}
# [round 320] test_metrics={'accuracy': DeviceArray(0.88412017, dtype=float32), 'loss': DeviceArray(0.35406902, dtype=float32)}
# [round 330]
# [round 330] train_metrics={'accuracy': DeviceArray(0.84785277, dtype=float32), 'loss': DeviceArray(0.42576706, dtype=float32)}
# [round 330] test_metrics={'accuracy': DeviceArray(0.82722515, dtype=float32), 'loss': DeviceArray(0.46391162, dtype=float32)}
# [round 340]
# [round 340] train_metrics={'accuracy': DeviceArray(0.84894663, dtype=float32), 'loss': DeviceArray(0.44717035, dtype=float32)}
# [round 340] test_metrics={'accuracy': DeviceArray(0.8715953, dtype=float32), 'loss': DeviceArray(0.39554754, dtype=float32)}
# [round 350]
# [round 350] train_metrics={'accuracy': DeviceArray(0.84838074, dtype=float32), 'loss': DeviceArray(0.42153168, dtype=float32)}
# [round 350] test_metrics={'accuracy': DeviceArray(0.83404255, dtype=float32), 'loss': DeviceArray(0.45643008, dtype=float32)}
# [round 360]
# [round 360] train_metrics={'accuracy': DeviceArray(0.8466764, dtype=float32), 'loss': DeviceArray(0.47069246, dtype=float32)}
# [round 360] test_metrics={'accuracy': DeviceArray(0.87394965, dtype=float32), 'loss': DeviceArray(0.50723815, dtype=float32)}
# [round 370]
# [round 370] train_metrics={'accuracy': DeviceArray(0.8372427, dtype=float32), 'loss': DeviceArray(0.46375296, dtype=float32)}
# [round 370] test_metrics={'accuracy': DeviceArray(0.8257262, dtype=float32), 'loss': DeviceArray(0.5697283, dtype=float32)}
# [round 380]
# [round 380] train_metrics={'accuracy': DeviceArray(0.8335902, dtype=float32), 'loss': DeviceArray(0.54290545, dtype=float32)}
# [round 380] test_metrics={'accuracy': DeviceArray(0.8, dtype=float32), 'loss': DeviceArray(0.5771987, dtype=float32)}
# [round 390]
# [round 390] train_metrics={'accuracy': DeviceArray(0.82901555, dtype=float32), 'loss': DeviceArray(0.50553423, dtype=float32)}
# [round 390] test_metrics={'accuracy': DeviceArray(0.85643566, dtype=float32), 'loss': DeviceArray(0.34414333, dtype=float32)}
# [round 400]
# [round 400] train_metrics={'accuracy': DeviceArray(0.85623, dtype=float32), 'loss': DeviceArray(0.4125045, dtype=float32)}
# [round 400] test_metrics={'accuracy': DeviceArray(0.8333333, dtype=float32), 'loss': DeviceArray(0.4293318, dtype=float32)}
# [round 410]
# [round 410] train_metrics={'accuracy': DeviceArray(0.85173506, dtype=float32), 'loss': DeviceArray(0.42433673, dtype=float32)}
# [round 410] test_metrics={'accuracy': DeviceArray(0.84090906, dtype=float32), 'loss': DeviceArray(0.424985, dtype=float32)}
# [round 420]
# [round 420] train_metrics={'accuracy': DeviceArray(0.8027381, dtype=float32), 'loss': DeviceArray(0.522112, dtype=float32)}
# [round 420] test_metrics={'accuracy': DeviceArray(0.8085106, dtype=float32), 'loss': DeviceArray(0.45085987, dtype=float32)}
# [round 430]
# [round 430] train_metrics={'accuracy': DeviceArray(0.8713751, dtype=float32), 'loss': DeviceArray(0.38147223, dtype=float32)}
# [round 430] test_metrics={'accuracy': DeviceArray(0.92338705, dtype=float32), 'loss': DeviceArray(0.29711846, dtype=float32)}
# [round 440]
# [round 440] train_metrics={'accuracy': DeviceArray(0.8788471, dtype=float32), 'loss': DeviceArray(0.35989532, dtype=float32)}
# [round 440] test_metrics={'accuracy': DeviceArray(0.90717304, dtype=float32), 'loss': DeviceArray(0.27843222, dtype=float32)}
# [round 450]
# [round 450] train_metrics={'accuracy': DeviceArray(0.86353594, dtype=float32), 'loss': DeviceArray(0.40229765, dtype=float32)}
# [round 450] test_metrics={'accuracy': DeviceArray(0.8405797, dtype=float32), 'loss': DeviceArray(0.48535988, dtype=float32)}
# [round 460]
# [round 460] train_metrics={'accuracy': DeviceArray(0.84429455, dtype=float32), 'loss': DeviceArray(0.4435874, dtype=float32)}
# [round 460] test_metrics={'accuracy': DeviceArray(0.84951454, dtype=float32), 'loss': DeviceArray(0.4956885, dtype=float32)}
# [round 470]
# [round 470] train_metrics={'accuracy': DeviceArray(0.8702749, dtype=float32), 'loss': DeviceArray(0.3743226, dtype=float32)}
# [round 470] test_metrics={'accuracy': DeviceArray(0.87593985, dtype=float32), 'loss': DeviceArray(0.32451355, dtype=float32)}
# [round 480]
# [round 480] train_metrics={'accuracy': DeviceArray(0.8271131, dtype=float32), 'loss': DeviceArray(0.5239481, dtype=float32)}
# [round 480] test_metrics={'accuracy': DeviceArray(0.7535545, dtype=float32), 'loss': DeviceArray(0.6542299, dtype=float32)}
# [round 490]
# [round 490] train_metrics={'accuracy': DeviceArray(0.83832043, dtype=float32), 'loss': DeviceArray(0.44330204, dtype=float32)}
# [round 490] test_metrics={'accuracy': DeviceArray(0.8235295, dtype=float32), 'loss': DeviceArray(0.46928003, dtype=float32)}
# [round 500]
# [round 500] train_metrics={'accuracy': DeviceArray(0.8376229, dtype=float32), 'loss': DeviceArray(0.5194305, dtype=float32)}
# [round 500] test_metrics={'accuracy': DeviceArray(0.8623482, dtype=float32), 'loss': DeviceArray(0.38898784, dtype=float32)}
# [round 510]
# [round 510] train_metrics={'accuracy': DeviceArray(0.85464823, dtype=float32), 'loss': DeviceArray(0.39038107, dtype=float32)}
# [round 510] test_metrics={'accuracy': DeviceArray(0.8888889, dtype=float32), 'loss': DeviceArray(0.32971185, dtype=float32)}
# [round 520]
# [round 520] train_metrics={'accuracy': DeviceArray(0.809318, dtype=float32), 'loss': DeviceArray(0.50702846, dtype=float32)}
# [round 520] test_metrics={'accuracy': DeviceArray(0.79497904, dtype=float32), 'loss': DeviceArray(0.6153453, dtype=float32)}
# [round 530]
# [round 530] train_metrics={'accuracy': DeviceArray(0.8598048, dtype=float32), 'loss': DeviceArray(0.38314342, dtype=float32)}
# [round 530] test_metrics={'accuracy': DeviceArray(0.85714287, dtype=float32), 'loss': DeviceArray(0.47027025, dtype=float32)}
# [round 540]
# [round 540] train_metrics={'accuracy': DeviceArray(0.85966676, dtype=float32), 'loss': DeviceArray(0.38021764, dtype=float32)}
# [round 540] test_metrics={'accuracy': DeviceArray(0.8722467, dtype=float32), 'loss': DeviceArray(0.37988117, dtype=float32)}
# [round 550]
# [round 550] train_metrics={'accuracy': DeviceArray(0.8345206, dtype=float32), 'loss': DeviceArray(0.49036962, dtype=float32)}
# [round 550] test_metrics={'accuracy': DeviceArray(0.8428572, dtype=float32), 'loss': DeviceArray(0.51289135, dtype=float32)}
# [round 560]
# [round 560] train_metrics={'accuracy': DeviceArray(0.84744847, dtype=float32), 'loss': DeviceArray(0.45484683, dtype=float32)}
# [round 560] test_metrics={'accuracy': DeviceArray(0.864486, dtype=float32), 'loss': DeviceArray(0.437586, dtype=float32)}
# [round 570]
# [round 570] train_metrics={'accuracy': DeviceArray(0.84259653, dtype=float32), 'loss': DeviceArray(0.40284348, dtype=float32)}
# [round 570] test_metrics={'accuracy': DeviceArray(0.8597786, dtype=float32), 'loss': DeviceArray(0.38189054, dtype=float32)}
# [round 580]
# [round 580] train_metrics={'accuracy': DeviceArray(0.8807947, dtype=float32), 'loss': DeviceArray(0.33696967, dtype=float32)}
# [round 580] test_metrics={'accuracy': DeviceArray(0.8584071, dtype=float32), 'loss': DeviceArray(0.34927207, dtype=float32)}
# [round 590]
# [round 590] train_metrics={'accuracy': DeviceArray(0.8431936, dtype=float32), 'loss': DeviceArray(0.44339433, dtype=float32)}
# [round 590] test_metrics={'accuracy': DeviceArray(0.8208955, dtype=float32), 'loss': DeviceArray(0.58307207, dtype=float32)}
# [round 600]
# [round 600] train_metrics={'accuracy': DeviceArray(0.86327505, dtype=float32), 'loss': DeviceArray(0.3925935, dtype=float32)}
# [round 600] test_metrics={'accuracy': DeviceArray(0.8663595, dtype=float32), 'loss': DeviceArray(0.4622543, dtype=float32)}
# [round 610]
# [round 610] train_metrics={'accuracy': DeviceArray(0.8282879, dtype=float32), 'loss': DeviceArray(0.51945454, dtype=float32)}
# [round 610] test_metrics={'accuracy': DeviceArray(0.8755365, dtype=float32), 'loss': DeviceArray(0.46413726, dtype=float32)}
# [round 620]
# [round 620] train_metrics={'accuracy': DeviceArray(0.8654132, dtype=float32), 'loss': DeviceArray(0.38579977, dtype=float32)}
# [round 620] test_metrics={'accuracy': DeviceArray(0.87179494, dtype=float32), 'loss': DeviceArray(0.42167294, dtype=float32)}
# [round 630]
# [round 630] train_metrics={'accuracy': DeviceArray(0.85962373, dtype=float32), 'loss': DeviceArray(0.46701947, dtype=float32)}
# [round 630] test_metrics={'accuracy': DeviceArray(0.84453785, dtype=float32), 'loss': DeviceArray(0.4441674, dtype=float32)}
# [round 640]
# [round 640] train_metrics={'accuracy': DeviceArray(0.8394299, dtype=float32), 'loss': DeviceArray(0.49664658, dtype=float32)}
# [round 640] test_metrics={'accuracy': DeviceArray(0.83539104, dtype=float32), 'loss': DeviceArray(0.52340585, dtype=float32)}
# [round 650]
# [round 650] train_metrics={'accuracy': DeviceArray(0.8546484, dtype=float32), 'loss': DeviceArray(0.3785704, dtype=float32)}
# [round 650] test_metrics={'accuracy': DeviceArray(0.87242806, dtype=float32), 'loss': DeviceArray(0.32628354, dtype=float32)}
# [round 660]
# [round 660] train_metrics={'accuracy': DeviceArray(0.878248, dtype=float32), 'loss': DeviceArray(0.35650265, dtype=float32)}
# [round 660] test_metrics={'accuracy': DeviceArray(0.8538961, dtype=float32), 'loss': DeviceArray(0.3978243, dtype=float32)}
# [round 670]
# [round 670] train_metrics={'accuracy': DeviceArray(0.8757036, dtype=float32), 'loss': DeviceArray(0.32999167, dtype=float32)}
# [round 670] test_metrics={'accuracy': DeviceArray(0.8414635, dtype=float32), 'loss': DeviceArray(0.4275064, dtype=float32)}
# [round 680]
# [round 680] train_metrics={'accuracy': DeviceArray(0.8412042, dtype=float32), 'loss': DeviceArray(0.4236156, dtype=float32)}
# [round 680] test_metrics={'accuracy': DeviceArray(0.86734694, dtype=float32), 'loss': DeviceArray(0.3835062, dtype=float32)}
# [round 690]
# [round 690] train_metrics={'accuracy': DeviceArray(0.8483202, dtype=float32), 'loss': DeviceArray(0.41835302, dtype=float32)}
# [round 690] test_metrics={'accuracy': DeviceArray(0.8491379, dtype=float32), 'loss': DeviceArray(0.49299857, dtype=float32)}
# [round 700]
# [round 700] train_metrics={'accuracy': DeviceArray(0.86139065, dtype=float32), 'loss': DeviceArray(0.38926095, dtype=float32)}
# [round 700] test_metrics={'accuracy': DeviceArray(0.82000005, dtype=float32), 'loss': DeviceArray(0.46943733, dtype=float32)}
# [round 710]
# [round 710] train_metrics={'accuracy': DeviceArray(0.86687726, dtype=float32), 'loss': DeviceArray(0.36817825, dtype=float32)}
# [round 710] test_metrics={'accuracy': DeviceArray(0.88188976, dtype=float32), 'loss': DeviceArray(0.3563547, dtype=float32)}
# [round 720]
# [round 720] train_metrics={'accuracy': DeviceArray(0.8607907, dtype=float32), 'loss': DeviceArray(0.4059035, dtype=float32)}
# [round 720] test_metrics={'accuracy': DeviceArray(0.85559565, dtype=float32), 'loss': DeviceArray(0.45461613, dtype=float32)}
# [round 730]
# [round 730] train_metrics={'accuracy': DeviceArray(0.8377824, dtype=float32), 'loss': DeviceArray(0.4252483, dtype=float32)}
# [round 730] test_metrics={'accuracy': DeviceArray(0.8088889, dtype=float32), 'loss': DeviceArray(0.46143377, dtype=float32)}
# [round 740]
# [round 740] train_metrics={'accuracy': DeviceArray(0.85750633, dtype=float32), 'loss': DeviceArray(0.43512893, dtype=float32)}
# [round 740] test_metrics={'accuracy': DeviceArray(0.82017547, dtype=float32), 'loss': DeviceArray(0.53608143, dtype=float32)}
# [round 750]
# [round 750] train_metrics={'accuracy': DeviceArray(0.9002463, dtype=float32), 'loss': DeviceArray(0.3010213, dtype=float32)}
# [round 750] test_metrics={'accuracy': DeviceArray(0.89928055, dtype=float32), 'loss': DeviceArray(0.2856133, dtype=float32)}
# [round 760]
# [round 760] train_metrics={'accuracy': DeviceArray(0.8329886, dtype=float32), 'loss': DeviceArray(0.4545448, dtype=float32)}
# [round 760] test_metrics={'accuracy': DeviceArray(0.8214286, dtype=float32), 'loss': DeviceArray(0.39363596, dtype=float32)}
# [round 770]
# [round 770] train_metrics={'accuracy': DeviceArray(0.83699363, dtype=float32), 'loss': DeviceArray(0.46729594, dtype=float32)}
# [round 770] test_metrics={'accuracy': DeviceArray(0.83474576, dtype=float32), 'loss': DeviceArray(0.50157523, dtype=float32)}
# [round 780]
# [round 780] train_metrics={'accuracy': DeviceArray(0.8436441, dtype=float32), 'loss': DeviceArray(0.41336635, dtype=float32)}
# [round 780] test_metrics={'accuracy': DeviceArray(0.84074074, dtype=float32), 'loss': DeviceArray(0.38934153, dtype=float32)}
# [round 790]
# [round 790] train_metrics={'accuracy': DeviceArray(0.84942526, dtype=float32), 'loss': DeviceArray(0.42124575, dtype=float32)}
# [round 790] test_metrics={'accuracy': DeviceArray(0.88557214, dtype=float32), 'loss': DeviceArray(0.36644447, dtype=float32)}
# [round 800]
# [round 800] train_metrics={'accuracy': DeviceArray(0.8324217, dtype=float32), 'loss': DeviceArray(0.476555, dtype=float32)}
# [round 800] test_metrics={'accuracy': DeviceArray(0.82251084, dtype=float32), 'loss': DeviceArray(0.47908816, dtype=float32)}
# [round 810]
# [round 810] train_metrics={'accuracy': DeviceArray(0.86670387, dtype=float32), 'loss': DeviceArray(0.40054557, dtype=float32)}
# [round 810] test_metrics={'accuracy': DeviceArray(0.8413462, dtype=float32), 'loss': DeviceArray(0.5148389, dtype=float32)}
# [round 820]
# [round 820] train_metrics={'accuracy': DeviceArray(0.8516771, dtype=float32), 'loss': DeviceArray(0.43687013, dtype=float32)}
# [round 820] test_metrics={'accuracy': DeviceArray(0.8454545, dtype=float32), 'loss': DeviceArray(0.43064255, dtype=float32)}
# [round 830]
# [round 830] train_metrics={'accuracy': DeviceArray(0.85870075, dtype=float32), 'loss': DeviceArray(0.39045492, dtype=float32)}
# [round 830] test_metrics={'accuracy': DeviceArray(0.88477373, dtype=float32), 'loss': DeviceArray(0.36176583, dtype=float32)}
# [round 840]
# [round 840] train_metrics={'accuracy': DeviceArray(0.86414254, dtype=float32), 'loss': DeviceArray(0.36780506, dtype=float32)}
# [round 840] test_metrics={'accuracy': DeviceArray(0.86538464, dtype=float32), 'loss': DeviceArray(0.36823028, dtype=float32)}
# [round 850]
# [round 850] train_metrics={'accuracy': DeviceArray(0.8659852, dtype=float32), 'loss': DeviceArray(0.3340401, dtype=float32)}
# [round 850] test_metrics={'accuracy': DeviceArray(0.8341463, dtype=float32), 'loss': DeviceArray(0.44394764, dtype=float32)}
# [round 860]
# [round 860] train_metrics={'accuracy': DeviceArray(0.85292566, dtype=float32), 'loss': DeviceArray(0.43617463, dtype=float32)}
# [round 860] test_metrics={'accuracy': DeviceArray(0.85067874, dtype=float32), 'loss': DeviceArray(0.49460986, dtype=float32)}
# [round 870]
# [round 870] train_metrics={'accuracy': DeviceArray(0.83199567, dtype=float32), 'loss': DeviceArray(0.50096935, dtype=float32)}
# [round 870] test_metrics={'accuracy': DeviceArray(0.7906977, dtype=float32), 'loss': DeviceArray(0.6036787, dtype=float32)}
# [round 880]
# [round 880] train_metrics={'accuracy': DeviceArray(0.87551236, dtype=float32), 'loss': DeviceArray(0.35444593, dtype=float32)}
# [round 880] test_metrics={'accuracy': DeviceArray(0.87111115, dtype=float32), 'loss': DeviceArray(0.38032535, dtype=float32)}
# [round 890]
# [round 890] train_metrics={'accuracy': DeviceArray(0.8117994, dtype=float32), 'loss': DeviceArray(0.5361166, dtype=float32)}
# [round 890] test_metrics={'accuracy': DeviceArray(0.85353535, dtype=float32), 'loss': DeviceArray(0.3999448, dtype=float32)}
# [round 900]
# [round 900] train_metrics={'accuracy': DeviceArray(0.8875267, dtype=float32), 'loss': DeviceArray(0.3082619, dtype=float32)}
# [round 900] test_metrics={'accuracy': DeviceArray(0.8394495, dtype=float32), 'loss': DeviceArray(0.39930937, dtype=float32)}
# [round 910]
# [round 910] train_metrics={'accuracy': DeviceArray(0.86235565, dtype=float32), 'loss': DeviceArray(0.39860374, dtype=float32)}
# [round 910] test_metrics={'accuracy': DeviceArray(0.81200004, dtype=float32), 'loss': DeviceArray(0.5535841, dtype=float32)}
# [round 920]
# [round 920] train_metrics={'accuracy': DeviceArray(0.84229183, dtype=float32), 'loss': DeviceArray(0.4397151, dtype=float32)}
# [round 920] test_metrics={'accuracy': DeviceArray(0.8737374, dtype=float32), 'loss': DeviceArray(0.43838662, dtype=float32)}
# [round 930]
# [round 930] train_metrics={'accuracy': DeviceArray(0.8506204, dtype=float32), 'loss': DeviceArray(0.41434798, dtype=float32)}
# [round 930] test_metrics={'accuracy': DeviceArray(0.85775864, dtype=float32), 'loss': DeviceArray(0.39590424, dtype=float32)}
# [round 940]
# [round 940] train_metrics={'accuracy': DeviceArray(0.88169163, dtype=float32), 'loss': DeviceArray(0.356864, dtype=float32)}
# [round 940] test_metrics={'accuracy': DeviceArray(0.875576, dtype=float32), 'loss': DeviceArray(0.3321015, dtype=float32)}
# [round 950]
# [round 950] train_metrics={'accuracy': DeviceArray(0.82565594, dtype=float32), 'loss': DeviceArray(0.51210254, dtype=float32)}
# [round 950] test_metrics={'accuracy': DeviceArray(0.84343433, dtype=float32), 'loss': DeviceArray(0.43155092, dtype=float32)}
# [round 960]
# [round 960] train_metrics={'accuracy': DeviceArray(0.856449, dtype=float32), 'loss': DeviceArray(0.39742738, dtype=float32)}
# [round 960] test_metrics={'accuracy': DeviceArray(0.85514015, dtype=float32), 'loss': DeviceArray(0.3961784, dtype=float32)}
# [round 970]
# [round 970] train_metrics={'accuracy': DeviceArray(0.8517992, dtype=float32), 'loss': DeviceArray(0.3812275, dtype=float32)}
# [round 970] test_metrics={'accuracy': DeviceArray(0.86831284, dtype=float32), 'loss': DeviceArray(0.3356655, dtype=float32)}
# [round 980]
# [round 980] train_metrics={'accuracy': DeviceArray(0.85698694, dtype=float32), 'loss': DeviceArray(0.39706644, dtype=float32)}
# [round 980] test_metrics={'accuracy': DeviceArray(0.8293839, dtype=float32), 'loss': DeviceArray(0.42819417, dtype=float32)}
# [round 990]
# [round 990] train_metrics={'accuracy': DeviceArray(0.869379, dtype=float32), 'loss': DeviceArray(0.370096, dtype=float32)}
# [round 990] test_metrics={'accuracy': DeviceArray(0.8796296, dtype=float32), 'loss': DeviceArray(0.4125602, dtype=float32)}
# [round 1000]
# [round 1000] train_metrics={'accuracy': DeviceArray(0.8842795, dtype=float32), 'loss': DeviceArray(0.33305153, dtype=float32)}
# [round 1000] test_metrics={'accuracy': DeviceArray(0.8537736, dtype=float32), 'loss': DeviceArray(0.35504064, dtype=float32)}
# [round 1010]
# [round 1010] train_metrics={'accuracy': DeviceArray(0.82663184, dtype=float32), 'loss': DeviceArray(0.4504449, dtype=float32)}
# [round 1010] test_metrics={'accuracy': DeviceArray(0.80995476, dtype=float32), 'loss': DeviceArray(0.50524914, dtype=float32)}
# [round 1020]
# [round 1020] train_metrics={'accuracy': DeviceArray(0.8588057, dtype=float32), 'loss': DeviceArray(0.4410214, dtype=float32)}
# [round 1020] test_metrics={'accuracy': DeviceArray(0.872807, dtype=float32), 'loss': DeviceArray(0.43543136, dtype=float32)}
# [round 1030]
# [round 1030] train_metrics={'accuracy': DeviceArray(0.85540414, dtype=float32), 'loss': DeviceArray(0.42889056, dtype=float32)}
# [round 1030] test_metrics={'accuracy': DeviceArray(0.8559322, dtype=float32), 'loss': DeviceArray(0.42782745, dtype=float32)}
# [round 1040]
# [round 1040] train_metrics={'accuracy': DeviceArray(0.89361703, dtype=float32), 'loss': DeviceArray(0.29514536, dtype=float32)}
# [round 1040] test_metrics={'accuracy': DeviceArray(0.85514015, dtype=float32), 'loss': DeviceArray(0.44027087, dtype=float32)}
# [round 1050]
# [round 1050] train_metrics={'accuracy': DeviceArray(0.8601093, dtype=float32), 'loss': DeviceArray(0.40661278, dtype=float32)}
# [round 1050] test_metrics={'accuracy': DeviceArray(0.8726415, dtype=float32), 'loss': DeviceArray(0.35923615, dtype=float32)}
# [round 1060]
# [round 1060] train_metrics={'accuracy': DeviceArray(0.8637245, dtype=float32), 'loss': DeviceArray(0.40863648, dtype=float32)}
# [round 1060] test_metrics={'accuracy': DeviceArray(0.8361345, dtype=float32), 'loss': DeviceArray(0.48696497, dtype=float32)}
# [round 1070]
# [round 1070] train_metrics={'accuracy': DeviceArray(0.85867727, dtype=float32), 'loss': DeviceArray(0.41832855, dtype=float32)}
# [round 1070] test_metrics={'accuracy': DeviceArray(0.815534, dtype=float32), 'loss': DeviceArray(0.5052354, dtype=float32)}
# [round 1080]
# [round 1080] train_metrics={'accuracy': DeviceArray(0.87292814, dtype=float32), 'loss': DeviceArray(0.38692662, dtype=float32)}
# [round 1080] test_metrics={'accuracy': DeviceArray(0.85200006, dtype=float32), 'loss': DeviceArray(0.4437347, dtype=float32)}
# [round 1090]
# [round 1090] train_metrics={'accuracy': DeviceArray(0.8503899, dtype=float32), 'loss': DeviceArray(0.37456375, dtype=float32)}
# [round 1090] test_metrics={'accuracy': DeviceArray(0.8185654, dtype=float32), 'loss': DeviceArray(0.46360782, dtype=float32)}
# [round 1100]
# [round 1100] train_metrics={'accuracy': DeviceArray(0.86404586, dtype=float32), 'loss': DeviceArray(0.35850108, dtype=float32)}
# [round 1100] test_metrics={'accuracy': DeviceArray(0.8566308, dtype=float32), 'loss': DeviceArray(0.3376373, dtype=float32)}
# [round 1110]
# [round 1110] train_metrics={'accuracy': DeviceArray(0.8702471, dtype=float32), 'loss': DeviceArray(0.37107134, dtype=float32)}
# [round 1110] test_metrics={'accuracy': DeviceArray(0.8630706, dtype=float32), 'loss': DeviceArray(0.35781428, dtype=float32)}
# [round 1120]
# [round 1120] train_metrics={'accuracy': DeviceArray(0.87042105, dtype=float32), 'loss': DeviceArray(0.36929235, dtype=float32)}
# [round 1120] test_metrics={'accuracy': DeviceArray(0.88151664, dtype=float32), 'loss': DeviceArray(0.42448065, dtype=float32)}
# [round 1130]
# [round 1130] train_metrics={'accuracy': DeviceArray(0.8386261, dtype=float32), 'loss': DeviceArray(0.47783428, dtype=float32)}
# [round 1130] test_metrics={'accuracy': DeviceArray(0.82222223, dtype=float32), 'loss': DeviceArray(0.40873346, dtype=float32)}
# [round 1140]
# [round 1140] train_metrics={'accuracy': DeviceArray(0.8704431, dtype=float32), 'loss': DeviceArray(0.33991718, dtype=float32)}
# [round 1140] test_metrics={'accuracy': DeviceArray(0.8682927, dtype=float32), 'loss': DeviceArray(0.3348824, dtype=float32)}
# [round 1150]
# [round 1150] train_metrics={'accuracy': DeviceArray(0.8537314, dtype=float32), 'loss': DeviceArray(0.42280874, dtype=float32)}
# [round 1150] test_metrics={'accuracy': DeviceArray(0.8808291, dtype=float32), 'loss': DeviceArray(0.3721034, dtype=float32)}
# [round 1160]
# [round 1160] train_metrics={'accuracy': DeviceArray(0.865245, dtype=float32), 'loss': DeviceArray(0.38449278, dtype=float32)}
# [round 1160] test_metrics={'accuracy': DeviceArray(0.8809524, dtype=float32), 'loss': DeviceArray(0.3821895, dtype=float32)}
# [round 1170]
# [round 1170] train_metrics={'accuracy': DeviceArray(0.8638996, dtype=float32), 'loss': DeviceArray(0.3281872, dtype=float32)}
# [round 1170] test_metrics={'accuracy': DeviceArray(0.8625001, dtype=float32), 'loss': DeviceArray(0.37548316, dtype=float32)}
# [round 1180]
# [round 1180] train_metrics={'accuracy': DeviceArray(0.83915025, dtype=float32), 'loss': DeviceArray(0.4526763, dtype=float32)}
# [round 1180] test_metrics={'accuracy': DeviceArray(0.82017547, dtype=float32), 'loss': DeviceArray(0.5427477, dtype=float32)}
# [round 1190]
# [round 1190] train_metrics={'accuracy': DeviceArray(0.8449227, dtype=float32), 'loss': DeviceArray(0.42327183, dtype=float32)}
# [round 1190] test_metrics={'accuracy': DeviceArray(0.8421053, dtype=float32), 'loss': DeviceArray(0.4199992, dtype=float32)}
# [round 1200]
# [round 1200] train_metrics={'accuracy': DeviceArray(0.8631841, dtype=float32), 'loss': DeviceArray(0.3892334, dtype=float32)}
# [round 1200] test_metrics={'accuracy': DeviceArray(0.8491379, dtype=float32), 'loss': DeviceArray(0.4032117, dtype=float32)}
# [round 1210]
# [round 1210] train_metrics={'accuracy': DeviceArray(0.8433671, dtype=float32), 'loss': DeviceArray(0.43549573, dtype=float32)}
# [round 1210] test_metrics={'accuracy': DeviceArray(0.8611111, dtype=float32), 'loss': DeviceArray(0.40428218, dtype=float32)}
# [round 1220]
# [round 1220] train_metrics={'accuracy': DeviceArray(0.79518074, dtype=float32), 'loss': DeviceArray(0.5323541, dtype=float32)}
# [round 1220] test_metrics={'accuracy': DeviceArray(0.82857144, dtype=float32), 'loss': DeviceArray(0.5464073, dtype=float32)}
# [round 1230]
# [round 1230] train_metrics={'accuracy': DeviceArray(0.8800803, dtype=float32), 'loss': DeviceArray(0.3472127, dtype=float32)}
# [round 1230] test_metrics={'accuracy': DeviceArray(0.84782606, dtype=float32), 'loss': DeviceArray(0.41546378, dtype=float32)}
# [round 1240]
# [round 1240] train_metrics={'accuracy': DeviceArray(0.87431693, dtype=float32), 'loss': DeviceArray(0.35368294, dtype=float32)}
# [round 1240] test_metrics={'accuracy': DeviceArray(0.8691099, dtype=float32), 'loss': DeviceArray(0.39953992, dtype=float32)}
# [round 1250]
# [round 1250] train_metrics={'accuracy': DeviceArray(0.86344916, dtype=float32), 'loss': DeviceArray(0.37167382, dtype=float32)}
# [round 1250] test_metrics={'accuracy': DeviceArray(0.8418367, dtype=float32), 'loss': DeviceArray(0.41569433, dtype=float32)}
# [round 1260]
# [round 1260] train_metrics={'accuracy': DeviceArray(0.8708273, dtype=float32), 'loss': DeviceArray(0.33761987, dtype=float32)}
# [round 1260] test_metrics={'accuracy': DeviceArray(0.86497897, dtype=float32), 'loss': DeviceArray(0.35672867, dtype=float32)}
# [round 1270]
# [round 1270] train_metrics={'accuracy': DeviceArray(0.8663102, dtype=float32), 'loss': DeviceArray(0.35761994, dtype=float32)}
# [round 1270] test_metrics={'accuracy': DeviceArray(0.8744186, dtype=float32), 'loss': DeviceArray(0.34503087, dtype=float32)}
# [round 1280]
# [round 1280] train_metrics={'accuracy': DeviceArray(0.83613205, dtype=float32), 'loss': DeviceArray(0.48478526, dtype=float32)}
# [round 1280] test_metrics={'accuracy': DeviceArray(0.78, dtype=float32), 'loss': DeviceArray(0.48696017, dtype=float32)}
# [round 1290]
# [round 1290] train_metrics={'accuracy': DeviceArray(0.8752204, dtype=float32), 'loss': DeviceArray(0.33796123, dtype=float32)}
# [round 1290] test_metrics={'accuracy': DeviceArray(0.88461536, dtype=float32), 'loss': DeviceArray(0.33101672, dtype=float32)}
# [round 1300]
# [round 1300] train_metrics={'accuracy': DeviceArray(0.860865, dtype=float32), 'loss': DeviceArray(0.40026876, dtype=float32)}
# [round 1300] test_metrics={'accuracy': DeviceArray(0.8636363, dtype=float32), 'loss': DeviceArray(0.4204825, dtype=float32)}
# [round 1310]
# [round 1310] train_metrics={'accuracy': DeviceArray(0.8685355, dtype=float32), 'loss': DeviceArray(0.39673454, dtype=float32)}
# [round 1310] test_metrics={'accuracy': DeviceArray(0.85654014, dtype=float32), 'loss': DeviceArray(0.4629806, dtype=float32)}
# [round 1320]
# [round 1320] train_metrics={'accuracy': DeviceArray(0.8519856, dtype=float32), 'loss': DeviceArray(0.41148752, dtype=float32)}
# [round 1320] test_metrics={'accuracy': DeviceArray(0.7713005, dtype=float32), 'loss': DeviceArray(0.5609886, dtype=float32)}
# [round 1330]
# [round 1330] train_metrics={'accuracy': DeviceArray(0.8648889, dtype=float32), 'loss': DeviceArray(0.35986963, dtype=float32)}
# [round 1330] test_metrics={'accuracy': DeviceArray(0.848249, dtype=float32), 'loss': DeviceArray(0.43838212, dtype=float32)}
# [round 1340]
# [round 1340] train_metrics={'accuracy': DeviceArray(0.86967117, dtype=float32), 'loss': DeviceArray(0.3697694, dtype=float32)}
# [round 1340] test_metrics={'accuracy': DeviceArray(0.8911918, dtype=float32), 'loss': DeviceArray(0.34668618, dtype=float32)}
# [round 1350]
# [round 1350] train_metrics={'accuracy': DeviceArray(0.8739237, dtype=float32), 'loss': DeviceArray(0.37444142, dtype=float32)}
# [round 1350] test_metrics={'accuracy': DeviceArray(0.82010585, dtype=float32), 'loss': DeviceArray(0.486501, dtype=float32)}
# [round 1360]
# [round 1360] train_metrics={'accuracy': DeviceArray(0.79862237, dtype=float32), 'loss': DeviceArray(0.5093458, dtype=float32)}
# [round 1360] test_metrics={'accuracy': DeviceArray(0.78723407, dtype=float32), 'loss': DeviceArray(0.51517135, dtype=float32)}
# [round 1370]
# [round 1370] train_metrics={'accuracy': DeviceArray(0.88210225, dtype=float32), 'loss': DeviceArray(0.32414073, dtype=float32)}
# [round 1370] test_metrics={'accuracy': DeviceArray(0.8595041, dtype=float32), 'loss': DeviceArray(0.38311237, dtype=float32)}
# [round 1380]
# [round 1380] train_metrics={'accuracy': DeviceArray(0.8856756, dtype=float32), 'loss': DeviceArray(0.3555972, dtype=float32)}
# [round 1380] test_metrics={'accuracy': DeviceArray(0.87401575, dtype=float32), 'loss': DeviceArray(0.360443, dtype=float32)}
# [round 1390]
# [round 1390] train_metrics={'accuracy': DeviceArray(0.87974685, dtype=float32), 'loss': DeviceArray(0.3373521, dtype=float32)}
# [round 1390] test_metrics={'accuracy': DeviceArray(0.8776372, dtype=float32), 'loss': DeviceArray(0.3692905, dtype=float32)}
# [round 1400]
# [round 1400] train_metrics={'accuracy': DeviceArray(0.86790127, dtype=float32), 'loss': DeviceArray(0.37356338, dtype=float32)}
# [round 1400] test_metrics={'accuracy': DeviceArray(0.82198954, dtype=float32), 'loss': DeviceArray(0.58202344, dtype=float32)}
# [round 1410]
# [round 1410] train_metrics={'accuracy': DeviceArray(0.8601467, dtype=float32), 'loss': DeviceArray(0.3956947, dtype=float32)}
# [round 1410] test_metrics={'accuracy': DeviceArray(0.81276596, dtype=float32), 'loss': DeviceArray(0.4518784, dtype=float32)}
# [round 1420]
# [round 1420] train_metrics={'accuracy': DeviceArray(0.87944025, dtype=float32), 'loss': DeviceArray(0.2944458, dtype=float32)}
# [round 1420] test_metrics={'accuracy': DeviceArray(0.85714287, dtype=float32), 'loss': DeviceArray(0.3823362, dtype=float32)}
# [round 1430]
# [round 1430] train_metrics={'accuracy': DeviceArray(0.8761496, dtype=float32), 'loss': DeviceArray(0.33120108, dtype=float32)}
# [round 1430] test_metrics={'accuracy': DeviceArray(0.90052354, dtype=float32), 'loss': DeviceArray(0.3227403, dtype=float32)}
# [round 1440]
# [round 1440] train_metrics={'accuracy': DeviceArray(0.8364231, dtype=float32), 'loss': DeviceArray(0.46242586, dtype=float32)}
# [round 1440] test_metrics={'accuracy': DeviceArray(0.7867299, dtype=float32), 'loss': DeviceArray(0.54969615, dtype=float32)}
# [round 1450]
# [round 1450] train_metrics={'accuracy': DeviceArray(0.8784498, dtype=float32), 'loss': DeviceArray(0.35077935, dtype=float32)}
# [round 1450] test_metrics={'accuracy': DeviceArray(0.8894472, dtype=float32), 'loss': DeviceArray(0.27157488, dtype=float32)}
# [round 1460]
# [round 1460] train_metrics={'accuracy': DeviceArray(0.86501694, dtype=float32), 'loss': DeviceArray(0.35955733, dtype=float32)}
# [round 1460] test_metrics={'accuracy': DeviceArray(0.87439615, dtype=float32), 'loss': DeviceArray(0.37478495, dtype=float32)}
# [round 1470]
# [round 1470] train_metrics={'accuracy': DeviceArray(0.8707371, dtype=float32), 'loss': DeviceArray(0.3206857, dtype=float32)}
# [round 1470] test_metrics={'accuracy': DeviceArray(0.852381, dtype=float32), 'loss': DeviceArray(0.35178873, dtype=float32)}
# [round 1480]
# [round 1480] train_metrics={'accuracy': DeviceArray(0.8332212, dtype=float32), 'loss': DeviceArray(0.46054468, dtype=float32)}
# [round 1480] test_metrics={'accuracy': DeviceArray(0.8218391, dtype=float32), 'loss': DeviceArray(0.39631656, dtype=float32)}
# [round 1490]
# [round 1490] train_metrics={'accuracy': DeviceArray(0.877311, dtype=float32), 'loss': DeviceArray(0.36992058, dtype=float32)}
# [round 1490] test_metrics={'accuracy': DeviceArray(0.9029126, dtype=float32), 'loss': DeviceArray(0.2999341, dtype=float32)}
# [round 1500]
# [round 1500] train_metrics={'accuracy': DeviceArray(0.8575916, dtype=float32), 'loss': DeviceArray(0.3814816, dtype=float32)}
# [round 1500] test_metrics={'accuracy': DeviceArray(0.8914028, dtype=float32), 'loss': DeviceArray(0.4474282, dtype=float32)}
